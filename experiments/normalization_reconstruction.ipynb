# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
original_video_width = 1920
original_video_height = 1080
original_point_x = np.arange(0, 1920, 1920 / 30)
original_point_y = np.sin(original_point_x / 1920 * 2 * np.pi) * 1080 / 2 + 1080 / 2

oringal_points = np.array([original_point_x, original_point_y]).T

original_video_frame = np.random.randint(0, 255, (original_video_height, original_video_width, 3), dtype=np.uint8)

plt.figure(figsize=(10, 10))
plt.imshow(original_video_frame, alpha=0.5)
plt.scatter(original_point_x, original_point_y, c='r', s=5)
plt.show()

# %%
normalized_x = original_point_x / original_video_width
normalized_y = original_point_y / original_video_height
normalized_point = np.array([normalized_x, normalized_y]).T

# %%
reconstructed_video_width = 1024
reconstructed_video_height = 1024

reconstructed_point_x = normalized_x * reconstructed_video_width
reconstructed_point_y = normalized_y * reconstructed_video_height
reconstructed_points = np.array([reconstructed_point_x, reconstructed_point_y])

reconstructed_video_frame = np.random.randint(0, 255, (reconstructed_video_height, reconstructed_video_width, 3), dtype=np.uint8)

plt.figure(figsize=(10, 10))
plt.imshow(reconstructed_video_frame, alpha=0.5)
plt.scatter(reconstructed_point_x, reconstructed_point_y, c='r', s=10)
plt.show()
